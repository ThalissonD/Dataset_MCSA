# %% [markdown]
# <a href="https://colab.research.google.com/github/ThalissonD/Dataset_MCSA/blob/main/Projeto_TCC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Obtém os dados de FFT e target do Google Drive 
C0 = pd.read_excel('/content/drive/My Drive/Colab Notebooks/Datasets/C0_Dados_FFT.xlsx')
Target = pd.read_excel('/content/drive/My Drive/Colab Notebooks/Datasets/C0_Target_FFT.xlsx')

# Método head(). Visualiza as 5 primeiras linhas de cada arquivo
C0.head()

##Método info(). Descrevendo os dados de entrada, assim verificando a quantidade de linhas totais de cada dado.
C0.info()

##Verificação de campos zerados, na matriz
C0.isnull().sum()

## Método describe(). Mostra um resumo dos atributos numéricos
C0.describe()

##Buscando correlações (r de Pearson)
#varia de -1 a 1, quanto mais próximo de 1, significa que existe forte correlação positiva
corr_matrixC0 = C0.corr()
corr_matrixC0


##Separando os dados em vários arquivos e organizando-os em listas
label_names_C0 = ["Broca sem desgaste","Broca com desgaste"]
labels_C0 = Target["Target"]
feature_names_C0 = ["FFT01","FFT02","FFT03","FFT04","FFT05","FFT06","FFT07","FFT08","FFT09","FFT10","FFT11","FFT12","FFT13","FFT14","FFT15","FFT16","FFT17","FFT18","FFT19","FFT20",
                    "FFT21","FFT22","FFT23","FFT24","FFT25","FFT26","FFT27","FFT28","FFT29","FFT30","FFT31","FFT32","FFT33","FFT34","FFT35","FFT36","FFT37","FFT38","FFT39","FFT40",
                    "FFT41","FFT42","FFT43","FFT44","FFT45","FFT46","FFT47","FFT48","FFT49","FFT50","FFT51","FFT52","FFT53","FFT54","FFT55","FFT56","FFT57","FFT58","FFT59","FFT60",
                    "FFT61","FFT62","FFT63","FFT64","FFT65","FFT66","FFT67","FFT68","FFT69","FFT70","FFT71","FFT72","FFT73","FFT74","FFT75","FFT76","FFT77","FFT78","FFT79","FFT80",
                    "FFT81","FFT82","FFT83","FFT84","FFT85","FFT86","FFT87","FFT88","FFT89","FFT90","FFT91","FFT92","FFT93","FFT94","FFT95","FFT96","FFT97","FFT98","FFT99","FFT100",
                    "FFT101","FFT102","FFT103","FFT104","FFT105","FFT106","FFT107","FFT108","FFT109","FFT110","FFT111","FFT112","FFT113","FFT114","FFT115","FFT116","FFT117","FFT118","FFT119","FFT120",
                    "FFT121","FFT122","FFT123","FFT124","FFT125","FFT126","FFT127","FFT128","FFT129","FFT130","FFT131","FFT132","FFT133","FFT134","FFT135","FFT136","FFT137","FFT138","FFT139","FFT140",
                    "FFT141","FFT142","FFT143","FFT144","FFT145","FFT146","FFT147","FFT148","FFT149","FFT150","FFT151","FFT152","FFT153","FFT154","FFT155","FFT156","FFT157","FFT158","FFT159","FFT160",
                    "FFT161","FFT162","FFT163","FFT164","FFT165","FFT166","FFT167"]#...
feature_C0 = [C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],
              C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],
              C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],
              C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],
              C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],
              C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],
              C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],
              C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],
              C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"],C0["F"]]
for i in range(166):
  if i == 1:
    feature_C0[i] = C0["F"]
  if i >= 2:
    feature_C0[i] = C0["F."+str(i)]

## Organizando Dados em Conjuntos
## Conjunto de testes (test) que representa 40% do dataset original
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB #página 108 - Harrison (2020)
from sklearn.linear_model import SGDClassifier #página 86 - Gerón (2019)
from sklearn.svm import SVC #página 111 - Harrison (2020)
from sklearn.pipeline import Pipeline #página 153 - Gerón (2019)
from sklearn.svm import LinearSVC #página 153 - Gerón (2019)
from sklearn.preprocessing import PolynomialFeatures #página 153 - Gerón (2019)
from sklearn.preprocessing import StandardScaler #página 153 - Gerón (2019)
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.metrics import precision_recall_curve #página 93 - Gerón (2019)

## Dividir nossos dados
train, test, train_labels, test_labels = train_test_split(feature_C0,
                                                          labels_C0,
                                                          test_size=0.4,
                                                          random_state=42)


## Fazer previsões em Classificação Naive Bayes - pag.108 Harrison(2020)
# Inicializar nosso classificador
gnb = GaussianNB()
# Treinar nosso classificador
gnb.fit(train, train_labels)
# Fazer previsões em Classificação Gaussiana
preds_gnb = gnb.predict(test)
print(preds_gnb)
# Avaliar a precisão
print("Acurácia:", accuracy_score(test_labels, preds_gnb))
# Avaliar a Matriz Confusão
print("Matriz Confusão:")
print(confusion_matrix(test_labels, preds_gnb))
# Avaliar a Precisão
print("Precisão: ", precision_score(test_labels, preds_gnb))
# Avaliar a Revocação
print("Revocação: ", recall_score(test_labels, preds_gnb))
# Avaliar a F1
print("F1 (Média harmônica): ", f1_score(test_labels, preds_gnb))


## Fazer previsões em Classificação Gradiente Descendente Estocástico (SGD) - pag.86 Gerón(2019)
# Inicializar nosso classificador
sgd = SGDClassifier(random_state=42)
# Treinar nosso classificador
sgd.fit(train, train_labels)
# Fazer previsões em SGD
preds_sgd = sgd.predict(test)
print(preds_sgd)
# Avaliar a precisão
print("Acurácia:", accuracy_score(test_labels, preds_sgd))
# Avaliar a Matriz Confusão
print("Matriz Confusão:")
print(confusion_matrix(test_labels, preds_sgd))
# Avaliar a Precisão
print("Precisão: ", precision_score(test_labels, preds_sgd))
# Avaliar a Revocação
print("Revocação: ", recall_score(test_labels, preds_sgd))
# Avaliar a F1
print("F1 (Média harmônica): ", f1_score(test_labels, preds_sgd))


## Fazer previsões em Classificação SVM  - pag.111 Harrison(2020)
# Inicializar nosso classificador
svc = SVC(random_state=42, probability=True)
# Treinar nosso classificador
svc.fit(train, train_labels)
SVC(C=1.00,cache_size=200, class_weight=None,
    coef0=0.0, decision_function_shape='ovr',
    degree=10, gamma='scale', kernel='sigmoid', 
    max_iter=-1, probability=True, random_state=42,
    shrinking=True, tol=0.001, verbose=False)
# Fazer previsões em SVM
preds_svc = svc.predict(test)
print(preds_svc)
# Avaliar a precisão
print("Acurácia:", accuracy_score(test_labels, preds_svc))
# Avaliar a Matriz Confusão
print("Matriz Confusão:")
print(confusion_matrix(test_labels, preds_svc))
# Avaliar a Precisão
print("Precisão: ", precision_score(test_labels, preds_svc))
# Avaliar a Revocação
print("Revocação: ", recall_score(test_labels, preds_svc))
# Avaliar a F1
print("F1 (Média harmônica): ", f1_score(test_labels, preds_svc))


## Fazer previsões em Classificação SVM Não Linear - pag.153 Gerón(2019)
# Inicializar nosso classificador
polynomial_svm_clf = Pipeline([
                               ("poly_features", PolynomialFeatures(degree=2)),
                               ("scaler", StandardScaler()),
                               ("svm_clf", LinearSVC(C=10, loss="hinge"))
])
# Treinar nosso classificador
polynomial_svm_clf.fit(train, train_labels)
# Fazer previsões em SVM
preds_svc_clf = polynomial_svm_clf.predict(test)
print(preds_svc_clf)
# Avaliar a precisão
print("Acurácia:", accuracy_score(test_labels, preds_svc_clf))
# Avaliar a Matriz Confusão
print("Matriz Confusão:")
print(confusion_matrix(test_labels, preds_svc_clf))
# Avaliar a Precisão
print("Precisão: ", precision_score(test_labels, preds_svc_clf))
# Avaliar a Revocação
print("Revocação: ", recall_score(test_labels, preds_svc_clf))
# Avaliar a F1
print("F1 (Média harmônica): ", f1_score(test_labels, preds_svc_clf))


## Fazer previsões em Classificação Kernel Polinomial - pag.154 Gerón(2019)
# Inicializar nosso classificador
poly_kernel_svm_clf = Pipeline([
                                ("scaler", StandardScaler()),
                                ("svm_clf", SVC(kernel="poly", degree=3, coef0=1, C=5))
])
# Treinar nosso classificador
poly_kernel_svm_clf.fit(train, train_labels)
# Fazer previsões em SGD
preds_svm_clf = poly_kernel_svm_clf.predict(test)
print(preds_svm_clf)
# Avaliar a precisão
print("Acurácia:", accuracy_score(test_labels, preds_svm_clf))
# Avaliar a Matriz Confusão
print("Matriz Confusão:")
print(confusion_matrix(test_labels, preds_svm_clf))
# Avaliar a Precisão
print("Precisão: ", precision_score(test_labels, preds_svm_clf))
# Avaliar a Revocação
print("Revocação: ", recall_score(test_labels, preds_svm_clf))
# Avaliar a F1
print("F1 (Média harmônica): ", f1_score(test_labels, preds_svm_clf))


## Fazer previsões em Classificação Kernel RBF - pag.156 Gerón(2019)
# Inicializar nosso classificador
rbf_kernel_svm_clf = Pipeline([
                                ("scaler", StandardScaler()),
                                ("svm_clf", SVC(kernel="rbf", gamma=5, C=0.001))
])
# Treinar nosso classificador
rbf_kernel_svm_clf.fit(train, train_labels)
# Fazer previsões em SGD
preds_svm_rbf = rbf_kernel_svm_clf.predict(test)
print(preds_svm_rbf)
# Avaliar a precisão
print("Acurácia:", accuracy_score(test_labels, preds_svm_rbf))
# Avaliar a Matriz Confusão
print("Matriz Confusão:")
print(confusion_matrix(test_labels, preds_svm_rbf))
# Avaliar a Precisão
print("Precisão: ", precision_score(test_labels, preds_svm_rbf))
# Avaliar a Revocação
print("Revocação: ", recall_score(test_labels, preds_svm_rbf))
# Avaliar a F1
print("F1 (Média harmônica): ", f1_score(test_labels, preds_svm_rbf))
